# %%
import json
with open('compiled_courses.json', 'r') as j:
    data = json.load(j)

# %%
data['courses']
# Out:
# {'SDM EN 521AS': {'code': 'SDM EN 521AS',
#   'description': 'This lecture course provides the dental student with a clear understanding of the biological foundations of pulpal and periapical disease. The causes and progression of these problems are discussed. Diagnostic, therapeutic, preventative, and follow-up modalities are introduced.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'AS1'}]},
#  'SDM EN 521': {'code': 'SDM EN 521',
#   'description': 'This lecture course provides the dental student with a clear understanding of the biological foundations of pulpal and periapical disease. The causes and progression of these problems are discussed. Diagnostic, therapeutic, preventative, and follow-up modalities are introduced.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD2'}]},
#  'SDM EN 522AS': {'code': 'SDM EN 522AS',
#   'description': 'This simulated clinic course provides experience and skill development in the clinical therapeutic techniques being presented in the lecture course. Both extracted and artificial teeth mounted in simulated mannequin patients are utilized to prepare students for direct patient endodontic care.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'AS1'}]},
#  'SDM EN 522': {'code': 'SDM EN 522',
#   'description': 'This simulated clinic course provides experience and skill development in the clinical therapeutic techniques being presented in the lecture course. Both extracted and artificial teeth mounted in simulated mannequin patients are utilized to prepare students for direct patient endodontic care.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD2'}]},
#  'SDM EN 640AS': {'code': 'SDM EN 640AS',
#   'description': 'Didactic seminar and clinical patient experiences consist of the diagnosis and treatment of pulpal and periapical dental pathology requiring endodontic intervention. Specific focus of this course is on case selection, emergency endodontic therapy, specialty referral, non-surgical endodontic therapy, direct observation of clinical endodontic procedures in the predoctoral and postdoctoral setting, in addition to preparation for the endodontic component of clinical licensure exams.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'AS2'}]},
#  'SDM EN 640': {'code': 'SDM EN 640',
#   'description': 'Didactic seminar and clinical patient experiences consist of the diagnosis and treatment of pulpal and periapical dental pathology requiring endodontic intervention. Specific focus of this course is on case selection, emergency endodontic therapy, specialty referral, non-surgical endodontic therapy, direct observation of clinical endodontic procedures in the predoctoral and postdoctoral setting, in addition to preparation for the endodontic component of clinical licensure exams.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD4'}]},
#  'SDM EN 805': {'code': 'SDM EN 805',
#   'description': 'A series of 27 seminars based on intensive and comprehensive readings in the literature of endodontics covering all facets pertaining to the science and practice of endodontics. 1st, 2nd, 3rd and 4th sem.',
#   'units': 8,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 806': {'code': 'SDM EN 806',
#   'description': 'A series of 27 seminars based on intensive and comprehensive readings in the literature of endodontics covering all facets pertaining to the science and practice of endodontics. 1st, 2nd, 3rd and 4th sem.',
#   'units': 8,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 808': {'code': 'SDM EN 808',
#   'description': 'This course will provide a basis for understanding tooth embryology and the biological processes at the cellular and molecular levels. In addition, the course will bridge the basics of Endodontic biology with the innovations in devices, materials and skills, providing vivid examples of evidence-based Endodontics.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 815': {'code': 'SDM EN 815',
#   'description': 'Comprehensive series of lectures and laboratory exercises designed to provide the resident with the knowledge and technical skills to perform proficiently surgical endodontic procedures. The most current techniques and state-of-the-art instruments and materials available for endodontic surgery are discussed and used in the laboratory exercises.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 821': {'code': 'SDM EN 821',
#   'description': 'Monthly seminars that comprehensively review the most recent scientific literature pertaining to the practice of endodontics published in peer reviewed journals. 1st, 2nd, 3rd, and 4th sem.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 801': {'code': 'SDM EN 801',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM EN 822': {'code': 'SDM EN 822',
#   'description': 'Monthly seminars that comprehensively review the most recent scientific literature pertaining to the practice of endodontics published in peer reviewed journals. 1st, 2nd, 3rd, and 4th sem.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 802': {'code': 'SDM EN 802',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM EN 823': {'code': 'SDM EN 823',
#   'description': 'Weekly (EndoY1) or monthly (EndoY2) seminars that provide the opportunity for the postdoctoral endodontic resident to present and discuss his/her clinical cases. Relative scientific literature along with the clinical experience of the faculty is stressed in justifying the rationale for diagnosis, treatment planning, and management. The cases are discussed using an evidence based dentistry approach. 1st, 2nd, 3rd, and 4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 803': {'code': 'SDM EN 803',
#   'description': 'Prerequisite for the clinical program. Participation in endodontic procedures performed on extracted teeth where the resident gains the clinical skills and the scientific knowledge necessary to treat patients. Lectures and clinical demonstrations by the endodontic faculty cover an extensive range of clinical procedures. 1st sem.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 824': {'code': 'SDM EN 824',
#   'description': 'Weekly (EndoY1) or monthly (EndoY2) seminars that provide the opportunity for the postdoctoral endodontic student to present and discuss his/her clinical cases. Relative scientific literature along with the clinical experience of the faculty is stressed in justifying the rationale for diagnosis, treatment planning, and management. The cases are discussed using an evidence based dentistry approach. 1st, 2nd, 3rd, and 4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 804': {'code': 'SDM EN 804',
#   'description': 'Series of lectures presented to the residents enrolled in the Postdoctoral Program in Endodontics The intention of this course is to expose the resident to the most current information pertaining to such topics as: histology and physiology of the pulpodentinal complex, diagnosis and classification of endodontic pathoses, management of endodontic emergencies including traumatic injuries to the dentition, and fascial space infections of odontogenic origin. 1st and 2nd sem.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 911': {'code': 'SDM EN 911',
#   'description': 'Clinical management of nonsurgical and surgical endodontic cases. Special attention is given to the development of diagnostic skills and clinical endodontic facility and to the application of a therapeutic approach formed in conjunction with other dental specialties. By the end of the program the student is expected to become proficient in all clinical endodontic procedures using modern technology backed by evidence-based knowledge. 1st 2nd 3rd and 4th sem.',
#   'units': 10,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 810': {'code': 'SDM EN 810',
#   'description': '',
#   'units': 0.5,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 912': {'code': 'SDM EN 912',
#   'description': 'Clinical management of nonsurgical and surgical endodontic cases. Special attention is given to the development of diagnostic skills and clinical endodontic facility and to the application of a therapeutic approach formed in conjunction with other dental specialties. By the end of the program the student is expected to become proficient in all clinical endodontic procedures using modern technology backed by evidence based knowledge. 1st, 2nd, 3rd, and 4th sem..',
#   'units': 10,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 811': {'code': 'SDM EN 811',
#   'description': 'Develops logical approaches to endodontic diagnosis and treatment planning procedures. Includes discussion of a wide range of endodontic problems not usually encountered in clinical courses. 1st, 2nd, 3rd, and 4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 981': {'code': 'SDM EN 981',
#   'description': 'Approved research in endodontics. Designed as a partial requirement for the CAGS in endodontics. 1st-4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 812': {'code': 'SDM EN 812',
#   'description': 'Develops logical approaches to endodontic diagnosis and treatment planning procedures. Includes discussion of a wide range of endodontic problems not usually encountered in clinical courses. 1st, 2nd, 3rd, and 4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 982': {'code': 'SDM EN 982',
#   'description': 'Approved research in endodontics. Designed as a partial requirement for the CAGS in endodontics. 1st-4th sem.',
#   'units': 8,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 814': {'code': 'SDM EN 814',
#   'description': 'Presentation of rationale and operative procedures best employed in restoring endodontically treated teeth and in using them as long-term abutments for prosthetic appliances. 1st sem.',
#   'units': 0.5,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 991': {'code': 'SDM EN 991',
#   'description': 'Research in endodontics and related fields designed as a partial requirement for the MSD or DScD in endodontics. 1st-4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 819': {'code': 'SDM EN 819',
#   'description': 'Endodontics course for prosthodontists.',
#   'units': 0.5,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 992': {'code': 'SDM EN 992',
#   'description': 'Research in endodontics and related fields designed as a partial requirement for the MSD or DScD in endodontics. 1st-4th sem.',
#   'units': 8,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 820': {'code': 'SDM EN 820',
#   'description': 'Series of lectures and hands on sessions presented to the students enrolled in the advanced education program in general dentistry (AEGD) and the students enrolled in Post Graduate Operative and Esthetic Program (PGOE). Topics include: histology and physiology of the pulpodentinal complex; diagnostic procedures in the practice of endodontics; classification of pulpal and periradicular pathoses; management of endodontic emergencies; management of traumatic injuries to the dentition; lectures and hands-on focusing on the preparation and obturation of the root canal system; 1st sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 993': {'code': 'SDM EN 993',
#   'description': 'Research in endodontics and related fields designed as a partial requirement for the MSD or DScD in endodontics. 1st-4th sem.',
#   'units': 8,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM EN 825': {'code': 'SDM EN 825',
#   'description': 'Students are given the opportunity to enhance their diagnostic and manual skills in endodontics. Emphasis is placed on advanced concepts and theories in endodontics through a series of lectures, literature reviews and oral presentations by students.  The students also will be guided in diagnosis and treatment for their patients.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM GD 510': {'code': 'SDM GD 510',
#   'description': 'This course introduces first year students to basic concepts, skills, and attitudes necessary for the successful practice of dentistry. Didactic instruction includes introductions to the following topics: the language of dentistry, infection prevention, diagnosis & treatment planning, interpretation of the medical history, bacterial plaque formation, etiology and prevention of both dental caries and periodontal disease, critical thinking, oral & maxillofacial surgery, pediatric dentistry, fixed and removable prosthodontics, dental implants, orthodontics, cosmetic dentistry, and endodontics. Preclinical instruction is provided in the Simulation Learning Center using state of the art simulators and is focused on infection prevention, basic instrumentation skills, ergonomics, isolation techniques, general tooth preparation principles, simple amalgam restorations, and anterior and posterior composite resin restorations. There is also a Service Learning component where students are engaged in community service activities at grammar schools in the Boston area that are affiliated with BUGSDM. ',
#   'units': 6,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM EN 994': {'code': 'SDM EN 994',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 520AS': {'code': 'SDM GD 520AS',
#   'description': 'This course will review current techniques for incorporating CAD/CAM Technology into your everyday practice based on current literature. This course will be a blend of lecture series and hands on exercises. This format will ensure that the students are getting complete exposure and comprehensive learning to develop their skills, especially during the hands-on sections of this course.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': [{'code': 'DENT', 'value': 'AS1'}]},
#  'SDM EN 995': {'code': 'SDM EN 995',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 520': {'code': 'SDM GD 520',
#   'description': 'This course will review current techniques for incorporating CAD/CAM Technology into your everyday practice based on current literature. This course will be a blend of lecture series and hands on exercises. This format will ensure that the students are getting complete exposure and comprehensive learning to develop their skills, especially during the hands-on sections of this course.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD2'}]},
#  'SDM GD 580AS': {'code': 'SDM GD 580AS',
#   'description': "The didactic and practical course of Facial Injectables is a natural extension of the biomedical sciences curriculum. Anatomy, histology, embryology, pharmacology and biochemistry are requisite to the theory and delivery of injectable treatment. This course provides a comprehensive presentation of facial senescence, sexual dimorphism, and neurovascular elements of the head and neck. The daily practical sessions reinforce the basic tenets of successful patient treatment: exploration of patient chief complaint, diagnosis, selection of appropriate treatment modality, informed consent. Building on the student's requisite knowledge of anatomy, embryology, histology and pharmacology, the course presents a fundamental framework for safe and successful injectable treatment. This program requires the student to fully integrate and utilize information from the biomedical sciences learned in years 1 and 2. Mastery of those foundational subjects affirms the evidence that esthetic treatment outcomes are derived from the elegant accrual of anatomical and biological sciences.",
#   'units': 2,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': [{'code': 'DENT', 'value': 'AS2'}]},
#  'SDM GD 540AS': {'code': 'SDM GD 540AS',
#   'description': 'This course is designed to introduce to DMD II and DMD AS I students a broad overview of dental implants. The course will consist of a combination of didactic classroom learning and simulated lab exercises, which will teach students to read CBCT scans, treatment plan and place a virtual implant into the scan with merged data from a file of a digital impression of the dentition, and then to fabricate an accurate surgical guide for its use in guided surgery; place and restore dental implant on a model; as well as restore overdentures supported by dental implants. The course will prepare the students to treat patients in a clinical setting using dental implants as a treatment option.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'AS1'}]},
#  'SDM GD 580': {'code': 'SDM GD 580',
#   'description': "The didactic and practical course of Facial Injectables is a natural extension of the biomedical sciences curriculum. Anatomy, histology, embryology, pharmacology and biochemistry are requisite to the theory and delivery of injectable treatment. This course provides a comprehensive presentation of facial senescence, sexual dimorphism, and neurovascular elements of the head and neck. The daily practical sessions reinforce the basic tenets of successful patient treatment: exploration of patient chief complaint, diagnosis, selection of appropriate treatment modality, informed consent. Building on the student's requisite knowledge of anatomy, embryology, histology and pharmacology, the course presents a fundamental framework for safe and successful injectable treatment. This program requires the student to fully integrate and utilize information from the biomedical sciences learned in years 1 and 2. Mastery of those foundational subjects affirms the evidence that esthetic treatment outcomes are derived from the elegant accrual of anatomical and biological sciences. ",
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD3'}]},
#  'SDM GD 540': {'code': 'SDM GD 540',
#   'description': 'This course is designed to introduce to DMD II and DMD AS I students a broad overview of dental implants. The course will consist of a combination of didactic classroom learning and simulated lab exercises, which will teach students to read CBCT scans, treatment plan and place a virtual implant into the scan with merged data from a file of a digital impression of the dentition, and then to fabricate an accurate surgical guide for its use in guided surgery; place and restore dental implant on a model; as well as restore overdentures supported by dental implants. The course will prepare the students to treat patients in a clinical setting using dental implants as a treatment option.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD2'}]},
#  'SDM GD 606AS': {'code': 'SDM GD 606AS',
#   'description': 'This didactic course is designed to teach the DMD4s and AS2s esthetic treatment planning principles as well as to develop analytic skills in the diagnosis and clinical decision-making process on esthetic restorative treatment modalities that are offered to our patients. It is an elective, interdepartmental course, intended to be interactive, with active learning components through clinical case discussions.',
#   'units': 0,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 581AS': {'code': 'SDM GD 581AS',
#   'description': 'This course presents the concepts and techniques to enhance therapeutic and esthetic outcomes of dental treatment through the use of facial injectables. The course builds upon in-depth instruction in head and neck anatomy, physiology, biochemistry, and pharmacology that has previously been provided in the curriculum. The composition, biocompatibility and mode of action of the various biologic and synthetic injectables will be discussed, as will the indications and contraindications for using these as part of comprehensive dental treatment.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'AS2'}]},
#  'SDM GD 606': {'code': 'SDM GD 606',
#   'description': 'This didactic course is designed to teach the DMD4s and AS2s esthetic treatment planning principles as well as to develop analytic skills in the diagnosis and clinical decision-making process on esthetic restorative treatment modalities that are offered to our patients. It is an elective, interdepartmental course, intended to be interactive, with active learning components through clinical case discussions.',
#   'units': 0,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 581': {'code': 'SDM GD 581',
#   'description': 'This course presents the concepts and techniques to enhance therapeutic and esthetic outcomes of dental treatment through the use of facial injectables. The course builds upon in-depth instruction in head and neck anatomy, physiology, biochemistry, and pharmacology that has previously been provided in the curriculum. The composition, biocompatibility and mode of action of the various biologic and synthetic injectables will be discussed, as will the indications and contraindications for using these as part of comprehensive dental treatment.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD3'}]},
#  'SDM GD 801': {'code': 'SDM GD 801',
#   'description': 'An in-depth analysis of current issues in our aging population, including  demographic profiles, long-term care, financial considerations, and case  discussions. Articles from current literature will complement the information  discussed in the seminar. 2nd Sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM GD 582': {'code': 'SDM GD 582',
#   'description': 'The course provides practical, hands-on instruction designed to ensure the safe treatment of patients. Students will practice mock injections on each other, similar to when students learn to give local injections of anesthesia. This experience may be augmented by instruction using cadaver material. Typically, a surrogate neuromodulator (e.g. sterile saline) will be used, rather than active Botox?. Likewise, bacteriostatic saline will be used in the soft tissue filler exercises. The course hands-on training will occur in the GSDM Simulated Learning Center (SLC) and/or patient clinic, which will be reserved, as needed. ',
#   'units': 0,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD2'}]},
#  'SDM GD 804': {'code': 'SDM GD 804',
#   'description': 'IMPLM DGTL PRAC',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 640': {'code': 'SDM GD 640',
#   'description': 'This course is a major clinical experience in the DMD III year. Students apply the information learned in the curriculum up to this point and begin comprehensive care of assigned patients. This occurs under the auspice of the Group Practice Model, which is a patient-centered clinical education constructed for student-provided, faculty-guided high quality care of patients. Group Practice Leaders interact on a regular basis to document student progress towards competency. The emphasis is on ensuring that students are meeting interim educational goals and preparing to challenge structured summative assessments.',
#   'units': 10,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD3'}]},
#  'SDM MB 511': {'code': 'SDM MB 511',
#   'description': 'This course introduces the emerging science of molecular genetics. The course is designed to complement courses in microbiology, biochemistry, and immunology and to prepare the students to understand and assimilate knowledge being developed by researchers and the various implications for dental practice.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM GD 642AS': {'code': 'SDM GD 642AS',
#   'description': 'This course is designed to facilitate attainment of the various professional competencies each student must demonstrate prior to graduation. Clinically active students and their respective Group Practice Leaders interact on a regular basis to document student progress towards competency. This occurs under the auspice of the Group Practice Model, which is a patient-centered clinical education construct for student-provided, faculty-guided high quality care of patients. During the final year of the curriculum, the emphasis is on ensuring that students successively challenge structured summative assessments. Group Practice leaders are responsible for monitoring student progress, implementing corrective actions as needed, and authorizing that students have met the competency standards ("signing out") required for the degree. Students will also learn to integrate the knowledge they have acquired in their biomedical science courses in formulation of treatment planning and providing comprehensive patient care.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'AS2'}]},
#  'SDM MB 652AS': {'code': 'SDM MB 652AS',
#   'description': 'Intensive Research Elective Course (IREC) IREC provides intensive and structured research experiences throughout the dental school curriculum for predoctoral dental students interested in careers in oral health research. The objectives are: 1) to carry out well-defined research projects under the guidance of research mentors; 2) to enhance critical thinking skills; 3) to participate in the full range of research-related activities, including scientific meetings and journal clubs; 4) to train in the design and execution of scientific studies, gain better understanding of innovative dental techniques, materials and tools, and develop analytical thinking abilities; and 5) to contribute to the discovery of new knowledge and dissemination through the scientific literature. There are three IREC options: * IREC1 - Intensive Research DMD year 1 (as part of the APEX program) (3 credits); * IREC2 - Intensive Research DMD year 2 (2 credits); * IREC3 - Intensive Research DMD year 3 (2 credits). The long-range goals of IREC are to produce better informed dental clinicians with improved eligibility for academic appointments.',
#   'units': 2,
#   'prereqtext': {},
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 642': {'code': 'SDM GD 642',
#   'description': 'This course is designed to facilitate attainment of the various professional competencies each student must demonstrate prior to graduation. Clinically active students and their respective Group Practice Leaders interact on a regular basis to document student progress towards competency. This occurs under the auspice of the Group Practice Model, which is a patient-centered clinical education construct for student-provided, faculty-guided high quality care of patients. During the final year of the curriculum, the emphasis is on ensuring that students successively challenge structured summative assessments. Group Practice leaders are responsible for monitoring student progress, implementing corrective actions as needed, and authorizing that students have met the competency standards ("signing out") required for the degree. Students will also learn to integrate the knowledge they have acquired in their biomedical science courses in formulation of treatment planning and providing comprehensive patient care.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD4'}]},
#  'SDM MB 653AS': {'code': 'SDM MB 653AS',
#   'description': 'Intensive Research Elective Course (IREC) IREC provides intensive and structured research experiences throughout the dental school curriculum for predoctoral dental students interested in careers in oral health research. The objectives are: 1) to carry out well-defined research projects under the guidance of research mentors; 2) to enhance critical thinking skills; 3) to participate in the full range of research-related activities, including scientific meetings and journal clubs; 4) to train in the design and execution of scientific studies, gain better understanding of innovative dental techniques, materials and tools, and develop analytical thinking abilities; and 5) to contribute to the discovery of new knowledge and dissemination through the scientific literature. There are three IREC options: * IREC1 - Intensive Research DMD year 1 (as part of the APEX program) (3 credits); * IREC2 - Intensive Research DMD year 2 (2 credits); * IREC3 - Intensive Research DMD year 3 (2 credits). The long-range goals of IREC are to produce better informed dental clinicians with improved eligibility for academic appointments.',
#   'units': 2,
#   'prereqtext': {},
#   'offered': '',
#   'attributes': None},
#  'SDM GD 650AS': {'code': 'SDM GD 650AS',
#   'description': 'The Clinical Data Collection and Treatment Planning course is a clinical experience in the second year of the DMD Advanced Standing program. Students apply the information learned in the curriculum up to this point and begin treatment planning and sequencing treatment of their assigned patients. This occurs under the supervision of the faculty assigned in the rotation, within the patient treatment center.  The duration of the rotation is one week.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': [{'code': 'DENT', 'value': 'AS2'}]},
#  'SDM MB 802': {'code': 'SDM MB 802',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 650': {'code': 'SDM GD 650',
#   'description': 'The Clinical Data Collection and Treatment Planning course is a clinical experience in the third and fourth year of the DMD program. Students apply the information learned in the curriculum up to this point and begin treatment planning and sequencing treatment of their assigned patients. This occurs under the supervision of the faculty assigned in the rotation, within the patient treatment center.  The duration of the rotation is one week in the third year, and one week in the fourth year.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': [{'code': 'DENT', 'value': 'DMD3'},
#    {'code': 'DENT', 'value': 'DMD4'}]},
#  'SDM MB 803': {'code': 'SDM MB 803',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM MD 510': {'code': 'SDM MD 510',
#   'description': 'Anatomical Sciences I is the first in a series of two courses designed to provide students with a comprehensive understanding of human anatomy. Anatomical Sciences I covers the topics of human microscopic anatomy (histology) and neuroanatomy. In the microscopic anatomy portion of Anatomical Sciences I, students will be introduced to various histological methods and the impact these methods have on the appearance of histological preparations. Students will also be exposed to a systematic analytical approach to tissue and organ identification, with an emphasis on structure and function relationship. In the neuroanatomy portion of Anatomical Sciences I, the structure and function of both the peripheral and central nervous systems will be emphasized. Students will engage in a detailed exploration of the various sensory and motor systems, including a comprehensive study of cranial nerves and their clinical relevance to the field of dentistry. Critical thinking and clinical problem solving are emphasized throughout the course using clinical case studies from the literature. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM GD 660AS': {'code': 'SDM GD 660AS',
#   'description': 'The purpose of the course is to teach and have students demonstrate a deeper understanding of how critical thinking is an essential part of assessing information and decision making in the practice of dentistry.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'AS2'}]},
#  'SDM MD 520A': {'code': 'SDM MD 520A',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': None},
#  'SDM GD 660': {'code': 'SDM GD 660',
#   'description': 'The purpose of the course is to teach and have students demonstrate a deeper understanding of how critical thinking is an essential part of assessing information and decision making in the practice of dentistry. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD3'}]},
#  'SDM MD 520AS': {'code': 'SDM MD 520AS',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': None},
#  'SDM GD 810': {'code': 'SDM GD 810',
#   'description': 'Comprehensive patient care conference exploring diagnosis, treatment planning and management of ongoing clinical cases.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM MD 531BAS': {'code': 'SDM MD 531BAS',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 820': {'code': 'SDM GD 820',
#   'description': 'A weekly seminar and review of current and classic articles of different disciplines in general dentistry. 1st and 2nd sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM MD 531CAS': {'code': 'SDM MD 531CAS',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM GD 901': {'code': 'SDM GD 901',
#   'description': 'Course to address common changes in the oral cavity encountered in older adults with disabilities. Recommendations for appropriate oral hygiene for adults with disabilities and their caretakers. Treatment Considerations Specific to the aging population with disabilities. 2nd sem.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM MD 531': {'code': 'SDM MD 531',
#   'description': 'This course addresses the pharmacologic principles that underlie the appropriate clinical use of therapeutic agents. The efficacy and toxicity of major classes of drugs are covered with emphasis on implications in dentistry, including side effects in the oral cavity and drug interactions. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD3'}]},
#  'SDM GD 918': {'code': 'SDM GD 918',
#   'description': 'This course will give the graduate students the opportunity to teach dental students in both the pre-clinical and clinical arena. This experience will allow the graduate students to grow in a different dimension by learning not just how to perfect their skills but also to learn how to communicate their thoughts and ideas and transfer that knowledge to other colleagues. The ability to successfully communicate ones knowledge adds a dimension of advanced understanding beyond the level of learning and performing the fundamental tasks needed to be a competent clinician.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM OB 511A': {'code': 'SDM OB 511A',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': None},
#  'SDM MB 652': {'code': 'SDM MB 652',
#   'description': 'Intensive Research Elective Course (IREC) IREC provides intensive and structured research experiences throughout the dental school curriculum for predoctoral dental students interested in careers in oral health research. The objectives are: 1) to carry out well-defined research projects under the guidance of research mentors; 2) to enhance critical thinking skills; 3) to participate in the full range of research-related activities, including scientific meetings and journal clubs; 4) to train in the design and execution of scientific studies, gain better understanding of innovative dental techniques, materials and tools, and develop analytical thinking abilities; and 5) to contribute to the discovery of new knowledge and dissemination through the scientific literature. There are three IREC options: * IREC1 - Intensive Research DMD year 1 (as part of the APEX program) (3 credits); * IREC2 - Intensive Research DMD year 2 (2 credits); * IREC3 - Intensive Research DMD year 3 (2 credits). The long-range goals of IREC are to produce better informed dental clinicians with improved eligibility for academic appointments. ',
#   'units': 2,
#   'prereqtext': {},
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM OB 512': {'code': 'SDM OB 512',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM MB 653': {'code': 'SDM MB 653',
#   'description': 'Intensive Research Elective Course (IREC) IREC provides intensive and structured research experiences throughout the dental school curriculum for predoctoral dental students interested in careers in oral health research. The objectives are: 1) to carry out well-defined research projects under the guidance of research mentors; 2) to enhance critical thinking skills; 3) to participate in the full range of research-related activities, including scientific meetings and journal clubs; 4) to train in the design and execution of scientific studies, gain better understanding of innovative dental techniques, materials and tools, and develop analytical thinking abilities; and 5) to contribute to the discovery of new knowledge and dissemination through the scientific literature. There are three IREC options: * IREC1 - Intensive Research DMD year 1 (as part of the APEX program) (3 credits); * IREC2 - Intensive Research DMD year 2 (2 credits); * IREC3 - Intensive Research DMD year 3 (2 credits). The long-range goals of IREC are to produce better informed dental clinicians with improved eligibility for academic appointments. ',
#   'units': 2,
#   'prereqtext': {},
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM OB 520': {'code': 'SDM OB 520',
#   'description': 'The second-year course in oral biology expands on concepts introduced in the first year. Emphasizes specific oral structures and functions and introduces the biology of oral disease states. Includes a section on clinical nutrition as it relates to systemic diseases and oral health.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'DMD2'}]},
#  'SDM MD 511': {'code': 'SDM MD 511',
#   'description': 'This course covers a wide range of topics in human gross anatomy that are relevant to the practice of dentistry. Specifically, lectures will provide in- depth details of the embryology of major organ systems, anatomy of the thorax, abdomen, upper extremity, neck, head and oral and nasal cavities. In addition, the structure, function and details of bones and joints of the body will be covered. In the lab portion of this course, we have the invaluable opportunity to use cadavers to directly observe the anatomical structures discussed in lecture.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM OB 648': {'code': 'SDM OB 648',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM MD 512': {'code': 'SDM MD 512',
#   'description': 'This course is designed to acquaint the student with the basic principles of modern biochemistry. The topics to be covered include an introduction to biochemistry and its importance to understanding oral health as well as proteins, enzymes, DNA, RNA and protein synthesis, sugar and lipid metabolism, hormones and second messengers and connective tissue biochemistry. In addition to the traditional lecture format, students participate in case-based presentations designed to integrate clinical cases with the material presented in class. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM OB 700': {'code': 'SDM OB 700',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM MD 514': {'code': 'SDM MD 514',
#   'description': 'This course presents the physiology of cells, tissues, organs, and integrated body functions, including student led discussion of the physiological basis of clinical conditions. An integrated approach is also taken to the endocrine system including extensive discussion of fuel metabolism and reproductive physiology. Hormonal aberrations and their end results are presented in clinical correlations by students.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM OB 761': {'code': 'SDM OB 761',
#   'description': 'Distribution, ecology, and pathogenic potential of oral microbiota. Pathogenicity of components of bacterial plaque and their role in the development of oral diseases. Mechanisms of local and systematic resistance to pathogenic oral microbiota.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': None},
#  'SDM MD 515': {'code': 'SDM MD 515',
#   'description': 'The overall goals of this course are to provide students with: (1) a foundation in medical microbiology, including the nomenclature, structure, physiology, genetics, mechanisms of pathogenesis, and clinical manifestations associated with microorganisms (bacteria, fungi, viruses and parasites) that cause disease, and the role of the microbiome in health and disease; (2) an understanding of how the basic principles of microbiology are applied in the effective diagnosis, treatment and prevention of infectious diseases, and (3) a basic background in immunology including the functions and disorders of the immune system. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM OB 767': {'code': 'SDM OB 767',
#   'description': '',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM MD 520': {'code': 'SDM MD 520',
#   'description': 'This course covers the fundamental concepts of modern pathology and explains how to apply the process of differential diagnosis in the major human diseases. Pathologic mechanisms and principles of most organs and systems of the body are discussed, with emphasis on those most relevant to oral health and care of dental patients. The course includes lectures by the School of Medicine Pathology faculty and Integrated Problem Sessions presented by students.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM OB 830': {'code': 'SDM OB 830',
#   'description': "Identifies and defines the components and uses of research protocol, the underlying research methodology and data, and the construction of a prudent work schedule essential to complete a research project. Includes the development of a protocol based on the student's thesis topic. ",
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM MD 530': {'code': 'SDM MD 530',
#   'description': 'This course addresses the pharmacological principles that underlie the appropriate clinical use of therapeutic agents. The efficacy and toxicity of major classes of drugs are covered with emphasis on implications in dentistry, including side effects in the oral cavity and drug interactions. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD2'}]},
#  'SDM OB 850': {'code': 'SDM OB 850',
#   'description': 'Weekly review and discussion of current pertinent literature in oral biology and related fields. 1st, 2nd, 3rd and 4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM MD 531AS': {'code': 'SDM MD 531AS',
#   'description': 'This course addresses the pharmacologic principles that underlie the appropriate clinical use of therapeutic agents. The efficacy and toxicity of major classes of drugs are covered with emphasis on implications in dentistry, including side effects in the oral cavity and drug interactions.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': [{'code': 'DENT', 'value': 'AS1'}]},
#  'SDM OB 852': {'code': 'SDM OB 852',
#   'description': 'Weekly review and discussion of current pertinent literature in oral biology and related fields. 1st, 2nd, 3rd and 4th sem.',
#   'units': 1,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM OB 511': {'code': 'SDM OB 511',
#   'description': 'This course is a comprehensive consideration of the embryology, microscopic and macroscopic structure, and functions of the orofacial complex. Material from the other basic sciences is expanded and related to the oral cavity. Emphasis is on the normal state of oral health. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': [{'code': 'DENT', 'value': 'DMD1'}]},
#  'SDM OB 900': {'code': 'SDM OB 900',
#   'description': '',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'SDM OB 763': {'code': 'SDM OB 763',
#   'description': 'Examines biological processes at the cellular and molecular levels. Provides a basis to understand the events that regulate inflammation; wound healing; bone formation and resorption; salivary proteins and their relevance to mineral homeostasis.; Oral immunology as it pertains to constructive and destructive oral tissues. 1st and 2nd sem.',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': [{'code': 'DENT', 'value': 'POSTDOC'}]},
#  'SDM OB 991': {'code': 'SDM OB 991',
# ...
#   'units': 0,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA ME 995S': {'code': 'CFA ME 995S',
#   'description': 'DMA DISSRTATION',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA ME 995': {'code': 'CFA ME 995',
#   'description': 'Last class (dissertation) in doctoral program. Selection of dissertation topic; research techniques; compilation of preliminary biography under direction of a dissertation supervisor. In subsequent semesters, students should register for ME996. [3 cr] ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA ME 996S': {'code': 'CFA ME 996S',
#   'description': 'DMA  Dissertation Continuation',
#   'units': 0,
#   'prereqtext': None,
#   'offered': 'SUM',
#   'attributes': None},
#  'CFA ME 996': {'code': 'CFA ME 996',
#   'description': 'Ongoing work toward completion of the DMA terminal project; dissertation, doctoral composition or comparable approved project. This is for students who have completed their first semester of dissertation work and are continuing to work toward completion of the degree. Students must register for ME996 in every semester through graduation. [0 cr] ',
#   'units': 0,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 609': {'code': 'CFA MH 609',
#   'description': 'Examines how Spirituals have served as essential touch points for all styles of African-American music, ranging from gospel to classical, and are even frequently samples in hip-hop. Students will study how African American classical composers, including Florence Price, visual artist Aaron David, choreographer Alvin Ailey and American novelist Toni Morrison have utilized spirituals as reference material through direct quotations, themes, variations and performances.\nBy focusing on this musical expression and the strength of human spirit expressed through this music, students will learn how enslaved peoples maintained their dignity, resisted the dehumanizing impact of slavery, and fought to preserve key cultural and linguistic elements even in the midst of the horrible oppression of slavery.\nFinally, students will examine why Spirituals have played a significant role as vehicles for protest at intermittent points during the twentieth and early twenty-first centuries around the world including Russia, Eastern Europe, China and South Africa. Some of today’s well-known pop artists continue to draw on the spirituals tradition in the creation of new protest songs. Examples include Bob Marley’s “Redemption Song” and Bill Bragg’s “Sing their souls back home.”',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'SPRG',
#   'attributes': None},
#  'CFA MH 613': {'code': 'CFA MH 613',
#   'description': 'This special topics engages with music, media, and technology. The specific topic will vary by semester.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 629': {'code': 'CFA MH 629',
#   'description': 'Mini-course offered by the Center for Early Music Studies. Taught by eminent figures in the field of early music, this course is an intensive, laboratory-style immersion in early music scholarship and performance on selected topics, composers, and repertories, covering vocal and instrumental styles from the Middle Ages to the end of the 18th century. 1 cr. Can be repeated for credit. ',
#   'units': 1,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 633': {'code': 'CFA MH 633',
#   'description': 'This special topics engages with the Western European Art music from the Baroque period. The specific topic will vary by semester.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 635': {'code': 'CFA MH 635',
#   'description': 'This special topics engages with aspects of Western art music of the Romantic period. The specific topic will vary by semester.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 651': {'code': 'CFA MH 651',
#   'description': 'This special topics engages with aspects of music in Asia. The specific topic will vary by semester.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 761': {'code': 'CFA MH 761',
#   'description': 'This course will involve in-depth reading and discussion of key areas of scholarship: music and politics, music and gender, music and religion, music and identity, and other useful paradigms. This course will broaden and deepen the intellectual horizons of graduate students in ethnomusicology and other interested graduate students. 3 cr.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 771': {'code': 'CFA MH 771',
#   'description': 'Case study of specifically defined areas in the forefront of ethnomusicological research. Individual research papers and class research projects as assigned by the instructor. 3 cr. May be repeated for credit.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 799': {'code': 'CFA MH 799',
#   'description': "Ongoing work toward completion of Master's Thesis. 3 cr. ",
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 837': {'code': 'CFA MH 837',
#   'description': "The course addresses elements and aspects of African-American music which extend beyond the confines of blues, including early rock'n'roll, hip-hop, 1940s big band jazz, and beyond. Additionally, the course incorporates a variety of intertextual elements, including literary cross-currents in African-American linguistic theory (as relevant to music), including Henry Louis Gates' seminal text Signifying Monkey and more.",
#   'units': 4,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 861': {'code': 'CFA MH 861',
#   'description': 'This graduate seminar is required for graduate students in Ethnomusicology. This course will involve in-depth reading and discussion of key areas of scholarship: music and politics, music and gender, music and religion, music and identity, and other useful paradigms. This course will broaden and deepen the intellectual horizons of graduate students in ethnomusicology and other interested graduate students. Ethnomusicology graduate students will often take this graduate seminar in their third semester, but it could also be taken earlier. [ 4 cr.]',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 871': {'code': 'CFA MH 871',
#   'description': 'Case study of specifically defined areas in the forefront of ethnomusicological research. Individual research papers and class research projects as assigned by the instructor. 4 cr. May be repeated for credit. ',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 899': {'code': 'CFA MH 899',
#   'description': 'Specialized, individually tailored and guided work on projects not connected with a thesis, dissertation or other terminal document, but of particular interest to the graduate student. Variable credit. ',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 601': {'code': 'CFA MH 601',
#   'description': 'Topics include the library, basic research materials, primary and secondary sources, reading and writing about music, editions and editing, and sound recordings. 2 cr.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 601S': {'code': 'CFA MH 601S',
#   'description': 'MUS RES TECH',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SUM',
#   'attributes': None},
#  'CFA MH 610': {'code': 'CFA MH 610',
#   'description': 'This course provides students with the tools to write about music across genres. Relying on existing examples, from various historical periods, of program notes, album liner notes, concert and album reviews, and academic, creative, and journalistic writing about music, students will learn the conventions of these different formats of musical writing and hone their own writing skills in order to write about music in the ways necessitated by their professional and personal goals.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 611': {'code': 'CFA MH 611',
#   'description': 'Explores the role of music and sound as social practice, political catalyst, market commodity, site of nostalgia, environment, identity tool, and technology of the self. Enables students to write about sound and music. Addresses music as mood manipulation; noise pollution; musical taste and identity; gendered music; “urban tribes” and musical subcultures; amateur vs. specialist music-making; the music industry; music as power; notions of authenticity; sound technology. Case studies may include: gym, study, and slow jam playlists; karaoke; the racial politics of crossover; Guitar Hero; music conservatories; mood music and “cock rock”; barbershop quartets; amateur brass bands; suburban heavy metal; Muzak; advertising jingles; car and café soundscapes.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 611S': {'code': 'CFA MH 611S',
#   'description': 'MUS RES TECH',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SUM',
#   'attributes': None},
#  'CFA MH 612': {'code': 'CFA MH 612',
#   'description': 'This special topics engages with aspects of popular music. The specific topic will vary by semester.',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 614': {'code': 'CFA MH 614',
#   'description': 'This special topics engages with themes related to music, dance, and the body. The specific topic will vary by semester.',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 620': {'code': 'CFA MH 620',
#   'description': 'This course will use original sources, a range of recordings, musicological scholarship, and performer testimonials to examine issues in early music performance through a series of case studies from ca. 1600 to around 1900.  We will look at the pertinent scholarship involved in preparing performances, the controversies that arise, and possible solutions.  In dealing with music before 1600, issues of instrumentation, notation, ornamentation, and context are both complicated and crucial, and we will examine the relevant scholarship and recordings.  After 1800, performance issues can be just as difficult to confirm.  One of the goals of the course is to introduce you to the value of using original sources and the many issues – execution, context, flexibility, tempo and other markings and choice of instrument – that arise from them, so that your own performances take into account the various historical issues that are critical for performing ¬– and teaching ¬– this repertoire.  The seminar-style course will be based around weekly assignments, student presentations, and classroom discussion.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 620S': {'code': 'CFA MH 620S',
#   'description': 'TPCS MUS STYLE',
#   'units': 4,
#   'prereqtext': None,
#   'offered': 'SUM',
#   'attributes': None},
#  'CFA MH 621': {'code': 'CFA MH 621',
#   'description': 'From backgrounds in organ, clavichord, and harpsichord, music of the Baroque period to sonatas and character pieces of Schubert. 3 cr.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 622': {'code': 'CFA MH 622',
#   'description': 'From piano music of Mendelssohn to contemporary repertory; emphasis on impact of virtuosity and perfection of idiomatic writing in the keyboard style of the nineteenth century. 3 cr.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 623': {'code': 'CFA MH 623',
#   'description': 'Rossini, Donizetti, and Bellini; sociopolitical backgrounds of Italian opera in the nineteenth century; Verdi: Aida, Otello, Falstaff; verismo and its exponents. Influence of Wagner on Italian opera; Giacomo Puccini. 3 cr.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 625': {'code': 'CFA MH 625',
#   'description': 'Comparison of Baroque, Classical, Romantic, and twentieth-century approaches to the concerto. Role of the virtuoso in development of the form. 3 cr.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 626': {'code': 'CFA MH 626',
#   'description': 'The German Lied, the French art song, and other European art songs in the nineteenth and twentieth centuries. Emphasis on Schubert, Schumann, Brahms, Wolf, Mussorgsky, Faure, and Debussy. 3.0 credits.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 627': {'code': 'CFA MH 627',
#   'description': 'Development of choral music from the Renaissance period to the present: motets, masses, madrigals, oratorios, cantatas, and combined media, sacred and secular. 3 cr. ',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 628': {'code': 'CFA MH 628',
#   'description': 'Historical development and close readings of the chamber music repertory from Baroque sonatas to contemporary works, for strings, winds, and mixed ensemble. 3 cr.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'FALL',
#   'attributes': None},
#  'CFA MH 630': {'code': 'CFA MH 630',
#   'description': 'This special topics engages with aspects of music in Europe. The specific topic will vary by semester.',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 631': {'code': 'CFA MH 631',
#   'description': 'This course will study the work of a single composer in depth, analyzing the work as a product both of individual style and of historical and cultural context. 3 cr. May be repeated for credit.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 632': {'code': 'CFA MH 632',
#   'description': '',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 634': {'code': 'CFA MH 634',
#   'description': 'This course explores topics related to Western Art Music in the Classical Period.',
#   'units': 3,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 636': {'code': 'CFA MH 636',
#   'description': 'This special topics engages with aspects of art music of the 20th century. The specific topic will vary by semester.',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 637': {'code': 'CFA MH 637',
#   'description': 'This special topics engages with aspects of art music after 1945. The specific topic will vary by semester.',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 659': {'code': 'CFA MH 659',
#   'description': 'This special topics engages with aspects of music in Africa. The specific topic will vary by semester.',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 660': {'code': 'CFA MH 660',
#   'description': 'This special topics engages with aspects of music in Latin America and/or the Caribbean. The specific topic will vary by semester.',
#   'units': 9,
#   'prereqtext': None,
#   'offered': 'BOTH',
#   'attributes': None},
#  'CFA MH 661': {'code': 'CFA MH 661',
#   'description': 'Through the experience of playing in a drumming circle led by a master drummer, students will learn authentic performance techniques and will gain confidence in rhythmic improvisation. Cultural, societal, and historical contexts will be studied informing students about the importance of drumming in all segments of African societies. 2 cr.',
#   'units': 2,
#   'prereqtext': None,
#   'offered': '',
#   'attributes': None},
#  'CFA MH 661S': {'code': 'CFA MH 661S',
#   'description': 'W AFR DRUMMING',
#   'units': 2,
#   'prereqtext': None,
#   'offered': 'SUM',
#   'attributes': None},
#  ...}

# %%
list(data['courses'].values()).__len__()
# Out:
# 20683

# %%
from random import shuffle

i: int = 0

a = list(data['courses'].values())

shuffle(a)

for c in a:

    if c['prereqtext']:

        i += 1 

        print(list(c['prereqtext'].values())[0], end='\n\n')

    if i == 200:
        break
# Out:
#  Graduate Prerequisites: QST SI718/750/751
#
# Undergraduate Prerequisites: admission to the Rabat Language and Liberal Arts program.
#
# Undergraduate Prerequisites: Limited to students enrolled in PhD in human physiology program.
#
# Undergraduate Prerequisites: junior standing, consent of instructor, and completed application.
#
# Undergraduate Prerequisites: (QSTFE323 & QSTMK323 & QSTOM323 & QSTQM323)
#
# Graduate Prerequisites: Core Curriculum and either MC775 or willingness to complete summer pre-course reading packet
# This course prepares the more advanced student to conduct public health research and for public health practice from an explicitly intersectional, racial/social justice-centered foundation. Students will advance their skills in transformative public health practice, critical research methods frameworks as well as policy, program and institutional evaluation using a number of established strategies and tools. Culminating projects will address key questions around systems of oppression and population patterns of health, and the capacity of programs, policies and organizations to disrupt or perpetuate health inequities.
#
# Undergraduate Prerequisites: CGS SS 201 or 202, or CAS AN 379, or CAS HI 364(formerly 390) or HI 48 7, or CAS EC 368, or CAS IR 365 or IR 368 or IR 370 or IR 520 or IR 52 7 or IR 585, or CAS PO 369 or PO 558 or PO 562, or consent.
#
# Undergraduate Prerequisites: CFA AR241
#
# Undergraduate Prerequisites: CAS AS 312; First Year Writing Seminar (e.g., WR 100 or WR 120)
#
#  Graduate Prerequisites: graduate standing.
#
# Undergraduate Prerequisites: junior or senior standing and at least two previous sociology courses; or consent of instructor.
#
# Undergraduate Prerequisites: First-Year Writing Seminar (e.g. CAS WR 120) or transfer credit for CAS WR 13* or CAS WR 16*. Topics vary. For detailed summer course descriptions, please visit https://www.bu.edu/summer/courses/writing/. Effective Spring 2022, this course fulfills a single unit in each of the following BU Hub areas: Creativity/Innovation, Writing, Research, and Inquiry, Research and Information Literacy.
#
#  Graduate Prerequisites: (QSTMX710)
#
# Undergraduate Prerequisites: (CASAR101) , or consent of instructor.
#
# Undergraduate Prerequisites: (CASLX250) or consent of instructor.
#
#  Graduate Prerequisites: SPH core course requirements in biostatistics and epidemiology.
#
# Undergraduate Prerequisites: (CASLI350 OR CASLI351 OR CASLI352)
#
# Undergraduate Prerequisites: (CASEN222)
#
# Undergraduate Prerequisites: First-Year Writing Seminar (WR 120 or equivalent).
#
#  Graduate Prerequisites: consent of instructor and the department chair
#
#  Graduate Prerequisites: approval of program director prior to registration.
#
# Undergraduate Prerequisites: (CASAN351 OR CASLX250) or consent of instructor.
#
# Undergraduate Prerequisites: one philosophy course or sophomore standing.
#
#  Graduate Prerequisites: (SSWHB720) or permission of department chair.
#
# Undergraduate Prerequisites: CASEC201 or EC501, or equivalent; CASEC203 or EC303 or EC507, or equi valent; CASEC391 or EC591, or equivalent; CASMA121 or MA123 or CASMA12 7 or EC505, or equivalent; or consent of instructor.
#
# Undergraduate Prerequisites: (MET CS 555 & MET CS 677).
#
#  Graduate Prerequisites: OTD degree students only.
#
# Undergraduate Prerequisites: First-Year Writing Seminar (CAS WR 120 or equivalent)
#
# Prerequisites: MET CS 566 or instructor’s consent.
#
# Undergraduate Prerequisites: at least 12 credits toward the MA in Global Development Policy or the MA in Global Development Economics
#
# Undergraduate Prerequisites: (CASAN101)
#
# Undergraduate Prerequisites: (CASLS212) or Spanish SAT subject test score of 560 or higher, or placement test results.
#
# Undergraduate Prerequisites: (CASCC101 & CASCC102) or two courses in religion or philosophy.
#
#  Graduate Prerequisites: consent of instructor
#
#  Graduate Prerequisites: completion of PhD qualifying examinations.
#
# Undergraduate Prerequisites: (CASLG350)
#
# Undergraduate Prerequisites: (COMCM217, CM417, CM501)
#
# Undergraduate Prerequisites: (QSTAC348)
#
# Undergraduate Prerequisites: First Year Writing Seminar (e.g., CAS EN 120 or WR 100 or WR 120), EN 220, EN 221, and EN322.
#
# Undergraduate Prerequisites: CAS MA 124; and CAS PY 211 or CAS PY 251.
#
# Undergraduate Prerequisites: enrollment in the Paris Internship Program.
#
# Undergraduate Prerequisites: OTD students only
#
# Undergraduate Prerequisites: CAS EE 270 or MA 115 or MA 213; or equivalent.
#
# Undergraduate Prerequisites: junior standing. At least one prior course in biblical or New Testamen t literature recommended.
#
#  Graduate Prerequisites: consent of instructor.
#
# Undergraduate Prerequisites: (CASPY351) First Year Writing Seminar (e.g., WR 100 or WR 120)
#
# Undergraduate Prerequisites: (CASLK111) or placement test results.
#
# Undergraduate Prerequisites: (CASLH212) or equivalent, or consent of instructor.
#
# Undergraduate Prerequisites: junior or senior standing and consent of instructor. Credits can vary
#
#  Graduate Prerequisites: MET AT722 and AT731 and cumulative GPA of 3.3 or higher and consent of instructor
#
# Undergraduate Prerequisites: CASCH 101.
#
#  Graduate Prerequisites: (SPHPH717) and BS723 or BS852; or consent of instructor
#
# Undergraduate Prerequisites: placement results.
#
# Undergraduate Prerequisites: (ENGEK301 & CASMA226)
#
#  Undergraduate Corequisites: (CASMA123)
#
#  Graduate Prerequisites: Open only to matriculated graduate students who have completed prerequ isites.
#
#  Graduate Prerequisites: (GRSIR603) or consent of instructor.
#
#  Graduate Prerequisites: Graduate standing.
#
#  Graduate Prerequisites: (QSTMX700)
#
# Undergraduate Prerequisites: (ENGEC414 & ENGEK381 & ENGEK103)
#
# Undergraduate Prerequisites: (ENGME303 OR ENGBE436) and ENGME304 or ENGEK424; and ENGME305 or ENGBE420, or by consent of i nstructor
#
# Undergraduate Prerequisites: (CASEC101 & CASEC102)
#
#  Graduate Prerequisites: SPH EP813 or consent of instructors
#
# Undergraduate Prerequisites: junior standing or consent of instructor. First Year Writing Seminar ( e.g., CAS WR 100 or WR 120).
#
# Undergraduate Prerequisites: enrollment in the Paris Internship Program.
#
# Undergraduate Prerequisites: consent of instructor, to whom two or three stories or a portion of a novel must be submitted during the period just before classes begin.
#
# Undergraduate Prerequisites: SHA HF 100 ;
#
#  Graduate Prerequisites: (QSTFE712 OR QSTFE722)
#
# Undergraduate Prerequisites: Junior or Senior standing required.
#
# Undergraduate
#
#  Graduate Prerequisites: biochemistry or physiology and consent of instructor
#
#  Graduate Prerequisites: consent of instructor
#
# Undergraduate Prerequisites: SARPT511, SARPT512, SARPT521, SARPT522, and SARHP532
#
# Undergraduate Prerequisites: consent of department and CAS Advising.
#
# Undergraduate Prerequisites: CASLF350 or equivalent, or consent of instructor. If registering for C ASLF469E: admission to the Paris Internship Program as well.
#
# Undergraduate Prerequisites: MET CS342 and at least one 500-level computer programming-intensive sc ience course (or instructor's consent). MET CS 564 or MET CS 565 are r ecommended.
#
# Undergraduate Prerequisites: consent of director of undergraduate studies.
#
# Undergraduate Prerequisites: consent of instructor and department.
#
# Undergraduate Prerequisites: (GRSCH621) (GRSCH622 recommended), or consent of instructor.
#
#  Graduate Prerequisites: CAS CH 203/204, CH 203/214, or CH 211/212; or equivalent, or consent o f the instructor.
#
# Undergraduate Prerequisites: (CASCH101 & CASCH102 & CASES144) or equivalents, and admission to the Marine Semester.
#
# Undergraduate Prerequisites: MET CS 201
#
# Undergraduate Prerequisites: (CASLS212) or Spanish SAT subject test score of 560 or higher, or placement test results.
#
#  Graduate Prerequisites: SPH BS858 or BS859; or consent of instructor
#
# Undergraduate Prerequisites: and two other philosophy courses, or consent of instructor.
#
# Undergraduate Prerequisites: (CASLS350) and two 400-level literature courses or consent of instructor.
#
# Undergraduate Prerequisites: MET AC 630 and MET FI 631
#
# Undergraduate Prerequisites: for GRS students only
#
# Undergraduate Prerequisites: (CASLI303)
#
#  Graduate Prerequisites: Graduate standing.
#
#  Graduate Prerequisites: (QSTMO712 OR QSTMO713)
#
#  Graduate Prerequisites: (SAROT904)
#
# Undergraduate Prerequisites: consent of WLL department and CAS Advising Office.
#
# Undergraduate Prerequisites: ENGEC312 & ENGEC450 or equivalent. ENGEC441 is desirable. C programmin g experience.
#
# Undergraduate Prerequisites: First Year Writing Seminar (e.g., WR 100 or WR 120)
#
# Undergraduate Prerequisites: admission to Cities Program (International Honors Program).
#
# Undergraduate Prerequisites: (QSTFE323)
#
#  Graduate Prerequisites: MPH students only. Minimum of 12 credits hours completed. Consent of s upervising faculty and signature of Practice Office (638-4656).
#
# Undergraduate Prerequisites: (CFAAR221 OR CFAAR223 OR CFAAR224)
#
# Undergraduate Prerequisites: acceptance into the Global Ecology Program (International Honors Progr am).
#
# Undergraduate Prerequisites: (CASEC201 & CASEC202) or consent of instructor.
#
# Undergraduate Prerequisites: (CASLF212) or equivalent; or placement test results.
#
# Undergraduate Prerequisites: native or near-native speakers of Spanish only.
#
# Undergraduate Prerequisites: (CASEC201) and one of CAS MA 121, 122, 123, 124, 127 or 129, or consent of instru ctor. Recommended: CAS EC 403.
#
# Undergraduate Prerequisites: SED SE 250
#
#  Graduate Prerequisites: Completion of at least 25 hours of approved coursework, approval by fa culty advisor, and submission of required documents to the Global Heal th Department.
#
# Undergraduate Prerequisites: (CASLH111) or the equivalent as determined by placement test.
#
# Undergraduate Prerequisites: Senior/graduate standing; CASCH101 or CASCH131; CASMA226; ENGME304 or ENGEK424; ENGME465 or ENGME529; or consent of instructor.
#
# Undergraduate Prerequisites: (CASLE312) or instructor consent.
#
#  Graduate Prerequisites: one year of New Testament Greek.
#
# Undergraduate Prerequisites: First-Year Writing Seminar (e.g., WR120)
#
#  Graduate Prerequisites: SPH PM702 or PH717
#
# Undergraduate Prerequisites: (COMCM215 OR COMCM217)
#
#  Graduate Prerequisites: (SSWCP755 & SSWCP756 & SSWCP757) For Traditional Track and HSE Students ; Graduate
#
# Undergraduate Prerequisites: Successful completion of all second year DPT coursework.
#
#  Graduate Prerequisites: MET AD741
#
# Undergraduate Prerequisites: acceptance into the Washington Internship or Journalism Program.
#
#  Graduate Prerequisites: consent of instructor and the department chair
#
# Undergraduate Prerequisites: junior standing or consent of instructor; First Year Writing Seminar ( e.g., WR 100 or WR 120)
#
#  Graduate Prerequisites: Pre-reqs: the MPH epidemiology and biostatistics core courses. Student s cannot take both IH744 and IH887.
#
#  Graduate Prerequisites: GMS FS 720 and GMS FS 721
#
# Undergraduate Prerequisites: enrollment in BU's Study Abroad/Internship Programs.
#
# Undergraduate Prerequisites: (CDSDS310 & CDSDS122 & CDSDS121)
#
#  Undergraduate Corequisites: Co-requisite for students taking CAS BB 402.
#
# Undergraduate Prerequisites: (CASPY351) or consent of instructor.
#
# Graduate Prerequisites: (SPHEP714 & SPHBS723) or SPH BS 730 or SPH PH 760 or SPH BS 805 or SPH BS 835; AND consent o f the instructor.
#
# Undergraduate Prerequisites: Limited to juniors, seniors, and graduate students. First Year Writing Seminar (e.g., WR 100 or WR 120)
#
# Undergraduate Prerequisites: (CASBI203 & CASBI206) and junior standing.
#
# Undergraduate Prerequisites: (CASPH310)
#
# Undergraduate Prerequisites: Senior standing; QST AC347
#
#  Graduate Prerequisites: consent of instructor and the department chair
#
#  Graduate Prerequisites: (SSWWP700 & SSWWP701) Or permission of department chair.
#
# Undergraduate Prerequisites: junior standing or consent of instructor.
#
#  Graduate Prerequisites: (SPHPH719 & SPHPH720) or consent of instructor.
#
# Undergraduate Prerequisites: First Year Writing Seminar (e.g., WR 100 or WR 120).
#
#  Graduate Prerequisites: SPH GH888 or permission of instructor
#
# Undergraduate Prerequisites: one previous literature course, or junior or senior standing. First-Ye ar Writing Seminar (e.g., WR120)
#
# Undergraduate Prerequisites: (CASPH350) or consent of instructor.
#
# Undergraduate Prerequisites: approval of College Honors Committee.
#
#  Graduate Prerequisites: consent of instructor
#
#  Graduate Prerequisites: consent of instructor and the department chair
#
# Undergraduate Prerequisites: consent of department and CAS Advising.
#
# Undergraduate Prerequisites: (SEDEC453) Approval Required
#
# Undergraduate Prerequisites: (CASPY541) or consent of instructor.
#
# Undergraduate Prerequisites: enrollment in the Dublin Internship Program. First Year Writing Semina r (e.g., WR 100 or WR 120)
#
# Undergraduate Prerequisites: QST MK323. Pre-req for SHA students: SHA HF260
#
# Undergraduate Prerequisites: Limited to students enrolled in the MS human physiology or nutrition p rograms.
#
# Undergraduate Prerequisites: Restrictions: Only for MS CIS students.
#
#  Graduate Prerequisites: PH740 or consent of instructor
#
# Graduate Prerequisites: consent of instructor
#
#  Graduate Prerequisites: (QSTFE712 OR QSTFE722)
#
# Undergraduate Prerequisites: enrollment in the Auckland Internship Program.
#
# Undergraduate Prerequisites: First Year Writing Seminar (e.g., WR 100 or WR 120)
#
# Undergraduate Prerequisites: (CASBI107) or equivalent.
#
# Undergraduate Prerequisites: Open to undergraduate students only. approval of advisor, the faculty member who is to supervise the study, and department chairman.
#
# Undergraduate Prerequisites: consent of instructor and advisor.
#
# Undergraduate Prerequisites: (QSTMO221)
#
# Undergraduate Prerequisites: admission to the SEA Semester; sophomore standing or consent of instr uctor.
#
#  Graduate Prerequisites: SHA HF 701
#
# Undergraduate Prerequisites: First Year Writing Seminar (e.g., WR 100 or WR 120)
#
# Undergraduate Prerequisites: First Year Writing Seminar (e.g., WR 100 or WR 120)
#
# Undergraduate Prerequisites: Advanced standing or consent of instructor
#
# Undergraduate Prerequisites: MET CS 201, or MET CS 231 or MET CS 232.
#
# Undergraduate Prerequisites: junior standing, First-Year Writing (e.g., WR 100 or WR 120), and eith er BI 351 or 341.
#
# Undergraduate Prerequisites: (CASSO203) or consent of instructor.
#
# Undergraduate Prerequisites: First Year Writing Seminar (e.g., CAS WR 100 or WR 120).
#
# Undergraduate Prerequisites: consent of department and CAS Academic Advising, 100 Bay State Rd., Ro om 401.
#
#  Graduate Prerequisites: For upper level MPH students who have basic proficiency with Excel
#
# Undergraduate Prerequisites: (CASNE102 & CASNE203) and NE major; and junior or senior standing.
#
# Undergraduate Prerequisites: junior standing or consent of instructor.
#
# Undergraduate Prerequisites: First-Year Writing Seminar (WR 120 or equivalent).
#
#  Graduate Prerequisites: consent of instructor
#
# Undergraduate Prerequisites: junior standing or consent of instructor.
#
# Undergraduate Prerequisites: (SARHS281) Limited to nutrition majors in the Dietetics Track. Cannot be taken fo r credit with SAR HS397.
#
#  Graduate Prerequisites: consent of instructor and the department chair
#
# Undergraduate Prerequisites: (ENGEK103 & CASMA225)
#
#  Graduate Prerequisites: Six completed program courses.
#
#  Graduate Prerequisites: Required of all students concurrently teaching SAR OT 320/520
#
# Undergraduate Prerequisites: JO200
#
# Undergraduate Prerequisites: For MS-SLP students only or with consent of the instructor.
#
# Undergraduate Prerequisites: high school biology and CAS CH 101 or equivalent
#
# Undergraduate Prerequisites: (QSTFE323 & QSTMK323 & QSTOM323 & QSTQM323)
#
# Undergraduate Prerequisites: ES/EE 107.
#
# Undergraduate Prerequisites: approval of CAS Honors Committee.
#
# Undergraduate Prerequisites: Admission to the MA program in translation or permission of instructor . First Year Writing Seminar (e.g., WR 100 or WR 120)
#
#  Graduate Prerequisites: MC725 or equivalent.
#
# Undergraduate Prerequisites: consent of instructor.
#
# Undergraduate Prerequisites: First-Year Writing Seminar (CASWR 120 or equivalent)
#
# Undergraduate Prerequisites: (CASLD216) or instructor consent.
#
# Undergraduate Prerequisites: First-Year Writing Seminar (e.g., WR 100 or WR 120).
#
#  Graduate Prerequisites: (SSWWP700 & SSWWP701) Or permission of department chair.
#
# Undergraduate Prerequisites: enrollment in the London Internship Program.
#
#  Graduate Prerequisites: consent of instructor, to whom one act or a full-length play must be s ubmitted during the period just before classes begin.
#
# Prerequisites: MET CS 544, or MET CS 555 or equivalent knowledge, or instructor's consent.
#
# Undergraduate Prerequisites: (ENGME366 OR CASMA381) & (ENGEK102 OR CASMA142))
#
#  Graduate Prerequisites: OTD degree students only.
#
# Undergraduate Prerequisites: one previous literature course or junior or senior standing.
#
# Undergraduate Prerequisites: (ENGME419)
#
#  Graduate Prerequisites: (SSWHB720 & SSWCP759)
#
# Undergraduate Prerequisites: one archaeology course or consent of instructor.

# %%
q = [
    "FT353 with a grade of B- or higher and one of the following: FT502 or FT508 or FT526 or FT565 or FT592 or FT593",
    "(CASMA226 & CASCH131) CAS PY313 preferred",
    "QST FE323, MK323, OM323, and QM323; First Year Writing Seminar (e.g., WR 100 or WR 120)",
    "GE/EE 100 or IR 292 or IR 590 and junior standing, or consent of instructor",
    "junior standing. Recommended: CAS BI 325 or BI 445 or BI 481.",
    "SPH SB721 and EP713, either concurrent or completed",
    "Two courses in classical civilization, or consent of instructor. First-Year Writing Seminar (e.g., WR 100 or WR 120).",
    "(CASMA121 & CASMA122) or (CASMA123 & CASMA124) or (CASNE 212) and soph. standing; or consent of instructor. CASNE212 or basic programming experience strongly encouraged.",
    "prior coursework in archaeology or ancient religions, or consent of instructor.",
    "Undergraduate Prerequisites: two 300-level Korean language courses (CAS LK 311, LK 312, LK 313, and LK 316), or consent of instructor.",
]

a = [ # Normal
    """{
    'prereqs': 'FT353&(FT502||FT508||FT526||FT565||FT592||FT593)',
    'consent_of_instructor': false,
    'recommended': '',
    'year': ''
    }""",
    """{ # Normal + Recommended
    'prereqs': '(CASMA226&CASCH131)',
    'consent_of_instructor': false,
    'recommended': 'CASPY313',
    'year': ''
    }
    """,
    """{
    'prereqs': '(QSTFE323&QSTMK323&QSTOM323&QSTQM323)&(WR100||WR120)',
    'consent_of_instructor': false,
    'recommended': '',
    'year': ''
    }
    """,
    """
    {
    'prereqs': '((GE100&EE100)||IR292||IR590)',
    'consent_of_instructor': true,
    'recommended': '',
    'year': 'junior'
    }
    """,
    """
    {
    'prereqs': '',
    'consent_of_instructor': false,
    'recommended': '(CASBI325||CASBI445||CASBI481)',
    'year': 'junior'
    }
    """,
    """
    {
    'prereqs': '{c}SPHSB721&{c}SPHEP713',
    'consent_of_instructor': false,
    'recommended': '',
    'year': ''
    }
    """,
    """
    {
    "prereqs": "{2}(lambda c, d, n: c == "CAS" & d == 'CL') & (WR100 || WR120)",
    "consent_of_instructor": true,
    "recommended": "",
    "year": ""
    }
    """, # (CASMA121 & CASMA122) or (CASMA123 & CASMA124) or (CASNE 212) and soph. standing; or consent of instructor. CASNE212 or basic programming experience strongly encouraged.
    """{
    "prereqs": "(CASMA121&CASMA122)||(CASMA123&CASMA124)||(CASNE 212)",
    "consent_of_instructor": true,
    "recommended": "CASNE212",
    "year": "sophmore"
    }
    """,
    """{
    "prereqs": "lambda c, d, n: c == "CAS" & d in ['AR', 'RN']",
    "consent_of_instructor": true,
    "recommended": "",
    "year": ""
    }
    """,
    """{
    "prereqs": "lambda c, d, n: c == "CAS" & d == "KL" & n > 300",
    "consent_of_instructor": true,
    "recommended": "",
    "year": ""
    }
    """,
]

for i, (ai, qi) in enumerate(zip(a, q)):

    print(
        f"Question: {i + 1}", 
        "Text",
        qi,
        "Correct JSON",
        "```json",
        ai,
        "```",
        f"End Question: {i + 1}",
        sep='\n'
)
# Out:
# Question: 1
# Text
# FT353 with a grade of B- or higher and one of the following: FT502 or FT508 or FT526 or FT565 or FT592 or FT593
# Correct JSON
# ```json
# {
#     'prereqs': 'FT353&(FT502||FT508||FT526||FT565||FT592||FT593)',
#     'consent_of_instructor': false,
#     'recommended': '',
#     'year': ''
#     }
# ```
# End Question: 1
# Question: 2
# Text
# (CASMA226 & CASCH131) CAS PY313 preferred
# Correct JSON
# ```json
# { # Normal + Recommended
#     'prereqs': '(CASMA226&CASCH131)',
#     'consent_of_instructor': false,
#     'recommended': 'CASPY313',
#     'year': ''
#     }
#
# ```
# End Question: 2
# Question: 3
# Text
# QST FE323, MK323, OM323, and QM323; First Year Writing Seminar (e.g., WR 100 or WR 120)
# Correct JSON
# ```json
# {
#     'prereqs': '(QSTFE323&QSTMK323&QSTOM323&QSTQM323)&(WR100||WR120)',
#     'consent_of_instructor': false,
#     'recommended': '',
#     'year': ''
#     }
#
# ```
# End Question: 3
# Question: 4
# Text
# GE/EE 100 or IR 292 or IR 590 and junior standing, or consent of instructor
# Correct JSON
# ```json
#
#     {
#     'prereqs': '((GE100&EE100)||IR292||IR590)',
#     'consent_of_instructor': true,
#     'recommended': '',
#     'year': 'junior'
#     }
#
# ```
# End Question: 4
# Question: 5
# Text
# junior standing. Recommended: CAS BI 325 or BI 445 or BI 481.
# Correct JSON
# ```json
#
#     {
#     'prereqs': '',
#     'consent_of_instructor': false,
#     'recommended': '(CASBI325||CASBI445||CASBI481)',
#     'year': 'junior'
#     }
#
# ```
# End Question: 5
# Question: 6
# Text
# SPH SB721 and EP713, either concurrent or completed
# Correct JSON
# ```json
#
#     {
#     'prereqs': '{c}SPHSB721&{c}SPHEP713',
#     'consent_of_instructor': false,
#     'recommended': '',
#     'year': ''
#     }
#
# ```
# End Question: 6
# Question: 7
# Text
# Two courses in classical civilization, or consent of instructor. First-Year Writing Seminar (e.g., WR 100 or WR 120).
# Correct JSON
# ```json
#
#     {
#     "prereqs": "{2}(lambda c, d, n: c == "CAS" & d == 'CL') & (WR100 || WR120)",
#     "consent_of_instructor": true,
#     "recommended": "",
#     "year": ""
#     }
#
# ```
# End Question: 7
# Question: 8
# Text
# (CASMA121 & CASMA122) or (CASMA123 & CASMA124) or (CASNE 212) and soph. standing; or consent of instructor. CASNE212 or basic programming experience strongly encouraged.
# Correct JSON
# ```json
# {
#     "prereqs": "(CASMA121&CASMA122)||(CASMA123&CASMA124)||(CASNE 212)",
#     "consent_of_instructor": true,
#     "recommended": "CASNE212",
#     "year": "sophmore"
#     }
#
# ```
# End Question: 8
# Question: 9
# Text
# prior coursework in archaeology or ancient religions, or consent of instructor.
# Correct JSON
# ```json
# {
#     "prereqs": "lambda c, d, n: c == "CAS" & d in ['AR', 'RN']",
#     "consent_of_instructor": true,
#     "recommended": "",
#     "year": ""
#     }
#
# ```
# End Question: 9
# Question: 10
# Text
# Undergraduate Prerequisites: two 300-level Korean language courses (CAS LK 311, LK 312, LK 313, and LK 316), or consent of instructor.
# Correct JSON
# ```json
# {
#     "prereqs": "lambda c, d, n: c == "CAS" & d == "KL" & n > 300",
#     "consent_of_instructor": true,
#     "recommended": "",
#     "year": ""
#     }
#
# ```
# End Question: 10
